# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
def explore_data(df):
    """Análise exploratória básica"""

    # Estatísticas descritivas
    print("Estatísticas Descritivas:")
    print(df.describe())

    # Verificar missing values
    print("\nMissing Values:")
    print(df.isnull().sum())

    # Visualizações
    fig, axes = plt.subplots(3, 1, figsize=(15, 10))

    # Preço de fechamento
    axes[0].plot(df.index, df['Close'])
    axes[0].set_title('Preço de Fechamento')

    # Volume
    axes[1].bar(df.index, df['Volume'])
    axes[1].set_title('Volume de Negociação')

    # Retornos diários
    df['Returns'] = df['Close'].pct_change()
    axes[2].plot(df.index, df['Returns'])
    axes[2].set_title('Retornos Diários')

    plt.tight_layout()
    plt.show()

# %%
df = pd.read_csv('../data/cache/AAPL.csv')

# %%
explore_data(df)
# Out:
# Estatísticas Descritivas:
#               Open         High          Low        Close        Volume
# count  1256.000000  1256.000000  1256.000000  1256.000000  1.256000e+03
# mean    179.531067   181.481808   177.757220   179.707093  7.085002e+07
# std      39.869336    40.151242    39.630367    39.923759  3.058431e+07
# min     116.449000   117.786000   113.676000   113.825000  1.791057e+07
# 25%     146.249250   148.003250   145.013000   146.521000  4.874051e+07
# 50%     171.926000   173.574000   170.256500   172.182500  6.418331e+07
# 75%     210.448750   212.928000   208.205750   210.317500  8.620258e+07
# max     286.200000   288.620000   283.300000   286.190000  3.193813e+08
#
# Missing Values:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64
